# %%
import pandas as pd
import datetime as dt
import re
import nltk
nltk.download('stopwords')
from nltk.corpus import stopwords 
from wordcloud import WordCloud
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.decomposition import LatentDirichletAllocation as LDA
from pyLDAvis import sklearn as sklearn_lda
import re
import os
import numpy as np
from nltk.corpus import stopwords 
from nltk.tokenize import word_tokenize
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_style('whitegrid')
# %matplotlib inline
from nltk import tokenize
import pyLDAvis
pyLDAvis.enable_notebook()
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\Choice\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
lista_arquivos = os.listdir('./Dados_Valor')

# %%
#df_total = pd.read_hdf('./Dados_Valor/Valor_2013-01-01_2013-01-30.hdf', key = 'hdf')
for i in lista_arquivos:
    df = pd.read_hdf(f'./Dados_Valor/{i}', key = 'hdf')
    df_total = pd.concat([df_total,df], ignore_index=True)

# %%
df_total.shape
# Out:
# (166282, 3)

# %%
df_total.dropna()
# Out:
#                        0                                                  1  \
# 0       30/01/2016 18h03  Filho de Lula critica a imprensa e defende o p...
# 1       29/01/2016 18h42  COI emite alerta a federações esportivas sobre...
# 2       29/01/2016 08h00             Cardápio renovado para atrair clientes
# 3       29/01/2016 08h00                           Mestres em transformação
# 4       29/01/2016 08h00  Lugar de estudante é o que tem boa conexão de ...
# 5       29/01/2016 08h00                            Estante do empreendedor
# 6       29/01/2016 08h00  Petrobras se reestrutura em busca de economia ...
# 7       29/01/2016 08h00                      O homem que falava 'djavanês'
# 8       29/01/2016 08h00               Técnica dosa conhecimento em pílulas
# 9       29/01/2016 08h00  Livros que estimulam as discussões na sala de ...
# 10      29/01/2016 08h00  Mattel diversifica visual da Barbie para recup...
# 11      29/01/2016 08h00                  Para IDC, setor deve crescer 2,6%
# 12      29/01/2016 08h00  Negócios de paletas se esforçam para não derreter
# 13      29/01/2016 08h00               Franquias de açaí chegam ao exterior
# 14      28/01/2016 21h56  Mercado de tecnologia no Brasil terá avanço de...
# 15      28/01/2016 13h54  Cade aprova Petrobras como parte interessada e...
# 16      28/01/2016 11h34  Inflação pelo IGP-M vai a 1,14% no começo de 2016
# 17      28/01/2016 10h35  Dilma reúne 92 conselheiros para sugestões par...
# 18      28/01/2016 08h00  Gerdau e grupos japoneses fazem parceria para ...
# 19      28/01/2016 08h00                              Commodities Agrícolas
# 20      27/01/2016 13h40  Fazenda defende legalidade das medidas para pa...
# 21      27/01/2016 08h00  Projetos que abrandam normas do trabalho ganha...
# 22      27/01/2016 08h00      Terceirização também é prioridade de empresas
# 23      27/01/2016 08h00  Eldorado Brasil tem o primeiro balanço anual c...
# 24      27/01/2016 08h00  Com ajuste, novas obras não devem sair do pape...
# 25      27/01/2016 08h00    Crise exige comunicação aberta com funcionários
# 26      26/01/2016 23h29  Equador propõe metas de desenvolvimento e divi...
# 27      26/01/2016 08h00                                          Destaques
# 28      26/01/2016 08h00     Empresas enfrentam ações coletivas no exterior
# 29      26/01/2016 08h00                                             Agenda
# ...                  ...                                                ...
# 166252  05/07/2019 18h53  Camaro não terá nova geração e deixará de ser ...
# 166253  05/07/2019 08h00                  Blockchain e o direito societário
# 166254  04/07/2019 22h24  Oposição quer que PGR apure se Moro mandou PF ...
# 166255  04/07/2019 08h00          Protocolo de Madri e empresas brasileiras
# 166256  04/07/2019 15h52  Salles vê 'inconsistências' e admite que Fundo...
# 166257  04/07/2019 14h28  Empresas atualizam rotinas em busca de mais ag...
# 166258  03/07/2019 16h54      Ibovespa sobe de olho na reforma; dólar recua
# 166259  03/07/2019 14h36  Tesla mostra virada em entregas, mas ainda há ...
# 166260  03/07/2019 13h12  Italiano David-Maria Sassoli é eleito presiden...
# 166261  03/07/2019 16h42   Moro levanta suspeita sobre invasões a celulares
# 166262  02/07/2019 20h53  Justiça condena empresas por divulgarem dados ...
# 166263  03/07/2019 11h44  Bolsonaro se nega a comentar tuítes do filho C...
# 166264  02/07/2019 21h41  Indicada a diretora do BC defende redução do c...
# 166265  03/07/2019 02h58  Moro diz na Câmara que hackers querem invalida...
# 166266  02/07/2019 13h44  Governo libera R$ 67,8 mi para vários ministérios
# 166267  02/07/2019 08h00      Liminar do TRF libera corretora de PIS/Cofins
# 166268  02/07/2019 08h01  Custo faz 10 milhões de pessoas fugirem das re...
# 166269  02/07/2019 08h01                 Cerveja artesanal dobrará até 2024
# 166270  02/07/2019 08h00           BB busca manter a coroa no crédito rural
# 166271  02/07/2019 03h31                                          Destaques
# 166272  01/07/2019 22h55  PF indicia assessores de ministro e candidatas...
# 166273  01/07/2019 21h50    Liminar do TRF libera corretora de PIS e Cofins
# 166274  01/07/2019 22h49        Carlos Bolsonaro lança suspeita sobre o GSI
# 166275  01/07/2019 17h52  Acordo Mercosul-UE beneficiará exportações bra...
# 166276  01/07/2019 13h28  Artigo: Sustentabilidade Fiscal da Reforma da ...
# 166277  01/07/2019 11h18               IPC-S fecha junho com baixa de 0,02%
# 166278  01/07/2019 15h00                Construtoras encolhem 85% em 3 anos
# 166279  01/07/2019 08h00        CCR admite falhas e busca corrigir a gestão
# 166280  25/07/2019 14h10  Venda de participação em ativos no Oriente Méd...
# 166281  04/07/2019 15h17      Executivas abrem espaço no mercado financeiro
#
#                                                         2
# 0       (Atualizada às 15h03) Fábio Luís Lula da Silva...
# 1       O Comitê Olímpico Internacional (COI) enviou u...
# 2                                         Entrar\nAssinar
# 3       "Só há duas coisas certas na vida: a morte e o...
# 4       A velha máxima de que "lugar de estudante é na...
# 5
# 6
# 7
# 8
# 9
# 10
# 11      A receita do mercado de tecnologia no Brasil p...
# 12      As paletas mexicanas, picolés grandes com sabo...
# 13      O interesse por alimentação saudável e natural...
# 14      O mercado de tecnologia no Brasil terá crescim...
# 15      A superintendência do Conselho Administrativo ...
# 16      A inflação medida pelo Índice Geral de Preços ...
# 17      O governo federal reativa hoje (28) o Conselho...
# 18
# 19      Vendas técnicas Contrariando mais uma vez os s...
# 20      O Ministério da Fazenda divulgou nota hoje def...
# 21
# 22
# 23      Três anos depois de iniciar a operação de sua ...
# 24
# 25
# 26      O presidente equatoriano, Rafael Correa, quer ...
# 27                                     Alienação parental
# 28      A listagem de empresas brasileiras no mercado ...
# 29      Comércio eletrônico\nA "Conferência E-commerce...
# ...                                                   ...
# 166252
# 166253  Muito já se falou a respeito da possibilidade ...
# 166254  Seis partidos da oposição pediram para que a P...
# 166255  As empresas brasileiras de todos os portes dev...
# 166256
# 166257  A inovação não cai do céu. Atentas a essa prem...
# 166258  O Ibovespa conseguiu opera em alta com parte d...
# 166259  A Tesla entregou mais carros elétricos no segu...
# 166260  Autor — Foto: AP Photo\nUm eurodeputado italia...
# 166261
# 166262  A Justiça do Trabalho tem condenado empresas q...
# 166263  O presidente Jair Bolsonaro se recusou a respo...
# 166264  A economista Fernanda Feitosa Nechio, indicada...
# 166265  Autor — Foto: AP Photo/Eraldo Peres\n(Atualiza...
# 166266  Autor — Foto: Reprodução / Facebook FGV-Ibre\n...
# 166267
# 166268
# 166269  A categoria de cervejas artesanais deve dobrar...
# 166270  Ante a inexorável tendência de redução do créd...
# 166271                               BR faz pré-pagamento
# 166272  A Polícia Federal indiciou nesta segunda-feira...
# 166273  A corretora de câmbio e valores mobiliários Ha...
# 166274  ((Atualizada às 19h48) Por meio do Twitter, o ...
# 166275  O acordo comercial firmado entre o Mercosul e ...
# 166276  O Brasil possui 80,9 milhões de pessoas ocupad...
# 166277  O Índice de Preços ao Consumidor Semanal (IPC-...
# 166278  As maiores construtoras brasileiras, que estiv...
# 166279  Em 2019, a CCR completa 20 anos com sua imagem...
# 166280  Em busca de um sócio estratégico para ingressa...
# 166281
#
# [166282 rows x 3 columns]
