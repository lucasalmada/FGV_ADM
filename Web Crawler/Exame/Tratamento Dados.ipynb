# %%
import pandas as pd

# %%
df1 = pd.read_hdf('EXAME_100pag.hdf', key = 'hdf')

# %%
df2 = pd.read_hdf('EXAME_100_300pag.hdf', key = 'hdf')

# %%
df2
# Out:
#                         0                                                  1  \
# 0      25 mar 2011, 11h37    STF terá novo desafio com candidatos condenados
# 1       2 out 2014, 15h54  Marina sobe o tom (literalmente) em último pro...
# 2       1 out 2014, 17h06  Foz do Iguaçu é eleita Melhor Destino de Ecotu...
# 3      15 out 2016, 08h00       Esta é a mansão mais cara dos Estados Unidos
# 4       8 ago 2014, 16h14  Governo negocia com bancos mais financiamento ...
# 5       5 out 2016, 16h00  Engenheiro conta por que não quis fazer um MBA...
# 6       3 jan 2011, 09h29  Cinemas terão cota maior de filmes brasileiros...
# 7       7 out 2016, 13h05  Google abre vagas para estagiários; veja como ...
# 8       4 set 2012, 19h50     Moody’s altera perspectiva da CSN para estável
# 9      29 dez 2010, 21h42  Grupo pede que americanos usem preservativos p...
# 10     19 ago 2014, 14h22  Ministério da Educação considera rever ensino ...
# ...

# %%
https://valor.globo.com/busca/?q=diversidade&species=not%C3%ADcias&order=recent&from=2019-01-01T00%3A00%3A00-0200&to=2019-10-30T23%3A59%3A59-0300&page=2&ajax=1
