# %%
import nltk
nltk.download('stopwords')
import PyPDF2 
import re
import os
import numpy as np
from wordcloud import WordCloud
from nltk.corpus import stopwords 
from nltk.tokenize import word_tokenize
import matplotlib.pyplot as plt
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\Choice\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
file_path = 'Artigos/Pasztor 2016 (1).pdf'

os.listdir('Artigos')
with open(file_path, mode='rb') as f:
    reader = PyPDF2.PdfFileReader(f)
    number_of_pages = reader.getNumPages()
    text = ''
    for i in range(number_of_pages - 5):
        page = reader.getPage(i)
        text += page.extractText()

# %%
words = text.split() #testar com word_vectorizer

#Colocar todas as palavras minúsculas
words = [x.lower() for x in words]

#Retirar pontuações
words = [re.sub('[,\.!?()]', '', x) for x in words]

#Retirar Stopwords
stop_words = set(stopwords.words('english'))
words = [x for x in words if x not in stop_words]

#Retirar números
words = [x for x in words if not re.search("\d", x)]

long_string = (" ").join(words)

# %%
wordcloud = WordCloud(background_color="white", max_words=4000, contour_width=20,width=1600, height=700, contour_color='steelblue')
wordcloud.generate(long_string)
wordcloud.to_image()
# Out:
# <PIL.Image.Image image mode=RGB size=1600x700 at 0x23329446F98>

# %%
long_string = (" ").join(words)

# %%
wordcloud.generate(long_string)

# %%
wordcloud = WordCloud(max_words=4000,width=1800, height=800, contour_width=10)
wordcloud.generate(long_string)
plt.figure( figsize=(20,10), facecolor='k')
plt.imshow(wordcloud)
plt.savefig('worcloud_Pasztor.png', facecolor='k', bbox_inches='tight')
